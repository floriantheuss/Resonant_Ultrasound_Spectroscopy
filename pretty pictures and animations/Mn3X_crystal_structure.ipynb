# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection
from matplotlib.colors import LightSource
# %matplotlib inline

# %%
a = 4
c = 6
epsilon = 0.1

length = 6
height = 8

size = 300 # size of circles in plots below

# %%
c = abs(c)
# points for scatter plot
# upper layer
Hexagon1s = np.array([[-a, 0, c/2], [-a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, c/2], [a, 0, c/2], [a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, c/2], [0, 0, c/2]])
Hexagon2s = np.array([[-a/2, 0, c/2], [-a/4, np.sqrt(3) * a/4, c/2], [a/4, np.sqrt(3) * a/4, c/2], [a/2, 0, c/2], [a/4, -np.sqrt(3) * a/4, c/2], [-a/4, -np.sqrt(3) * a/4, c/2], [0, np.sqrt(3)*a/2, c/2], [0, -np.sqrt(3)*a/2, c/2], [3*a/4, np.sqrt(3)*a/4, c/2], [-3*a/4, np.sqrt(3)*a/4, c/2], [3*a/4, -np.sqrt(3)*a/4, c/2], [-3*a/4, -np.sqrt(3)*a/4, c/2]])


# lower layer
c = -c
Hexagon3s = np.array([[-a, 0, c/2], [-a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, c/2], [a, 0, c/2], [a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, c/2], [0, 0, c/2]])
Hexagon4s = np.array([[-a/2, 0, c/2], [-a/4, np.sqrt(3) * a/4, c/2], [a/4, np.sqrt(3) * a/4, c/2], [a/2, 0, c/2], [a/4, -np.sqrt(3) * a/4, c/2], [-a/4, -np.sqrt(3) * a/4, c/2], [0, np.sqrt(3)*a/2, c/2], [0, -np.sqrt(3)*a/2, c/2], [3*a/4, np.sqrt(3)*a/4, c/2], [-3*a/4, np.sqrt(3)*a/4, c/2], [3*a/4, -np.sqrt(3)*a/4, c/2], [-3*a/4, -np.sqrt(3)*a/4, c/2]])

# middle layer
x = np.sqrt(3) * a/2 * 3/4
Hexagon5s = np.array([[a/2, -np.sqrt(3) * a/2 + x, 0], [-a/2, -np.sqrt(3) * a/2 + x, 0], [0, 0+x, 0]])

#Hexagon6s = np.array([[-a/2, 0+x, c/2], [-a/4, np.sqrt(3) * a/4+x, c/2], [a/4, np.sqrt(3) * a/4+x, c/2], [a/2, 0+x, c/2], [a/4, -np.sqrt(3) * a/4+x, c/2], [-a/4, -np.sqrt(3) * a/4+x, c/2], [0, -np.sqrt(3)*a/2+x, c/2], [3*a/4, np.sqrt(3)*a/4+x, c/2], [-3*a/4, np.sqrt(3)*a/4+x, c/2], [3*a/4, -np.sqrt(3)*a/4+x, c/2], [-3*a/4, -np.sqrt(3)*a/4+x, c/2]])

Hexagon6s = np.array([[-a/2, 0+x, 0], [a/2, 0+x, 0], [a/4, -np.sqrt(3) * a/4+x, 0], [-a/4, -np.sqrt(3) * a/4+x, 0], [0, -np.sqrt(3)*a/2+x, 0], [3*a/4, -np.sqrt(3)*a/4+x, 0], [-3*a/4, -np.sqrt(3)*a/4+x, 0], [-a/4, -3*np.sqrt(3)*a/4+x, 0], [a/4, -3*np.sqrt(3) * a/4+x, 0]])

# %%
# points for line plot
c = abs(c)
Hexagon1 = np.array([[-a, 0, c/2], [-a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, c/2], [a, 0, c/2], [a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, c/2], [-a, 0, c/2]])
Hexagon2 = np.array([[-a/2, 0, c/2], [-a/4, np.sqrt(3) * a/4, c/2], [a/4, np.sqrt(3) * a/4, c/2], [a/2, 0, c/2], [a/4, -np.sqrt(3) * a/4, c/2], [-a/4, -np.sqrt(3) * a/4, c/2],[-a/2, 0, c/2]])
Hexagon3 = np.array([[0, np.sqrt(3)*a/2, c/2], [0, -np.sqrt(3)*a/2, c/2], [3*a/4, np.sqrt(3)*a/4, c/2], [-3*a/4, np.sqrt(3)*a/4, c/2], [3*a/4, -np.sqrt(3)*a/4, c/2], [-3*a/4, -np.sqrt(3)*a/4, c/2]])

Hexagon4 = np.array([[-a/4, np.sqrt(3) * a/4, c/2], [0, np.sqrt(3)*a/2, c/2], [a/4, np.sqrt(3) * a/4, c/2], [3*a/4, np.sqrt(3)*a/4, c/2], [a/2, 0, c/2], [3*a/4, -np.sqrt(3)*a/4, c/2], [a/4, -np.sqrt(3) * a/4, c/2], [0, -np.sqrt(3)*a/2, c/2], [-a/4, -np.sqrt(3) * a/4, c/2], [-3*a/4, -np.sqrt(3)*a/4, c/2], [-a/2, 0, c/2], [-3*a/4, np.sqrt(3)*a/4, c/2], [-a/4, np.sqrt(3) * a/4, c/2]])

# lower level
c = -c
Hexagon5 = np.array([[-a, 0, c/2], [-a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, c/2], [a, 0, c/2], [a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, c/2], [-a, 0, c/2]])
Hexagon6 = np.array([[-a, 0, c/2], [-a, 0, -c/2]])
Hexagon7 = np.array([[-a/2, np.sqrt(3) * a/2, c/2], [-a/2, np.sqrt(3) * a/2, -c/2]])
Hexagon8 = np.array([[a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, -c/2]])
Hexagon9 = np.array([[a, 0, c/2], [a, 0, -c/2]])
Hexagon10 = np.array([[a/2, -np.sqrt(3) * a/2, c/2], [a/2, -np.sqrt(3) * a/2, -c/2]])
Hexagon11 = np.array([[-a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, -c/2]])

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection='3d')

ax.scatter3D(Hexagon1s[:,0], Hexagon1s[:,1], Hexagon1s[:,2], s=size, c='tab:blue', depthshade=False, zorder=1)
ax.scatter3D(Hexagon2s[:,0], Hexagon2s[:,1], Hexagon2s[:,2], s=size, c='tab:orange', depthshade=False, zorder=1)
ax.scatter3D(Hexagon3s[:,0], Hexagon3s[:,1], Hexagon3s[:,2], s=size, c='tab:blue', depthshade=False, zorder=0, alpha=1)
ax.scatter3D(Hexagon4s[:,0], Hexagon4s[:,1], Hexagon4s[:,2], s=size, c='tab:orange', depthshade=False, zorder=0, alpha=1)
ax.scatter3D(Hexagon5s[:,0], Hexagon5s[:,1], Hexagon5s[:,2], s=size, c='tab:blue', depthshade=False, zorder=0, alpha=0.3)
ax.scatter3D(Hexagon6s[:,0], Hexagon6s[:,1], Hexagon6s[:,2], s=size, c='tab:orange', depthshade=False, zorder=0, alpha=0.3)


ax.plot(Hexagon1[:,0], Hexagon1[:,1], Hexagon1[:,2], c='tab:blue', zorder=3)
ax.plot(Hexagon2[:,0], Hexagon2[:,1], Hexagon2[:,2], c='tab:orange', zorder=3)
ax.plot(Hexagon4[:,0], Hexagon4[:,1], Hexagon4[:,2], c='tab:orange', zorder=3)
ax.plot(Hexagon5[:,0], Hexagon5[:,1], Hexagon5[:,2], c='tab:blue', zorder=3)
ax.plot(Hexagon6[:,0], Hexagon6[:,1], Hexagon6[:,2], c='tab:blue', zorder=2)
ax.plot(Hexagon7[:,0], Hexagon7[:,1], Hexagon7[:,2], c='tab:blue', zorder=2)
ax.plot(Hexagon8[:,0], Hexagon8[:,1], Hexagon8[:,2], c='tab:blue', zorder=2)
ax.plot(Hexagon9[:,0], Hexagon9[:,1], Hexagon9[:,2], c='tab:blue', zorder=2)
ax.plot(Hexagon10[:,0], Hexagon10[:,1], Hexagon10[:,2], c='tab:blue', zorder=2)
ax.plot(Hexagon11[:,0], Hexagon11[:,1], Hexagon11[:,2], c='tab:blue', zorder=2)


m = max([a,c])
ax.scatter([m,m,m,m,-m,-m,-m,-m], [m,m,-m,-m,m,m,-m,-m], [m,-m,m,-m,m,-m,m,-m], s=0)

ax.view_init(30, 80)
ax.axis('off')
# Out:
# (-4.4, 4.4, -4.4, 4.4)

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection='3d')

N = 100
stride = 1
A = 0.1

u = np.linspace(0, 2*np.pi, N)
v = np.linspace(0, np.pi, N)

x = np.outer(np.cos(u), np.sin(v))
y = np.outer(np.sin(u), np.sin(v))
z = np.outer(np.ones(np.size(u)), np.cos(v))
ax.plot_surface(x, y, z, linewidth=0.0, alpha=0.5)#, cstride=stride, rstride=stride)

# plt.savefig('test.pdf')

# %%
import pyvista as pv

# %%
x = np.array([0,0,0])
y = np.array([5,0,0])
r = .5
specularpower = 1
opacity = .5
opacity1 = .5
opacity2 = 1
c1 = 'blue'
c2 = 'red'
c11 = 'grey'
c22 = 'purple'

resolution = 10

linewidth = 10



p = pv.Plotter()
pv.set_plot_theme("document")


# ----------------------------------------------------------------------------------------------------------------------------
# top layer
# ----------------------------------------------------------------------------------------------------------------------------
sphere = pv.Sphere(radius=r, center=[-a, 0, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/2, np.sqrt(3) * a/2, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, np.sqrt(3) * a/2, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a, 0, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, -np.sqrt(3) * a/2, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/2, -np.sqrt(3) * a/2, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, 0, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity, specular_power=specularpower)



sphere = pv.Sphere(radius=r, center=[-a/2, 0, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/4, np.sqrt(3) * a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/4, np.sqrt(3) * a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, 0, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/4, -np.sqrt(3) * a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/4, -np.sqrt(3) * a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, np.sqrt(3)*a/2, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, -np.sqrt(3)*a/2, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[3*a/4, np.sqrt(3)*a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-3*a/4, np.sqrt(3)*a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[3*a/4, -np.sqrt(3)*a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-3*a/4, -np.sqrt(3)*a/4, c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity, specular_power=specularpower)



# ----------------------------------------------------------------------------------------------------------------------------
# bottom layer
# ----------------------------------------------------------------------------------------------------------------------------
sphere = pv.Sphere(radius=r, center=[-a, 0, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/2, np.sqrt(3) * a/2, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, np.sqrt(3) * a/2, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a, 0, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, -np.sqrt(3) * a/2, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/2, -np.sqrt(3) * a/2, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, 0, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower)



sphere = pv.Sphere(radius=r, center=[-a/2, 0, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/4, np.sqrt(3) * a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/4, np.sqrt(3) * a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, 0, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2)

sphere = pv.Sphere(radius=r, center=[a/4, -np.sqrt(3) * a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/4, -np.sqrt(3) * a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, np.sqrt(3)*a/2, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, -np.sqrt(3)*a/2, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[3*a/4, np.sqrt(3)*a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-3*a/4, np.sqrt(3)*a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[3*a/4, -np.sqrt(3)*a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-3*a/4, -np.sqrt(3)*a/4, -c/2], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c2, smooth_shading=True, opacity=opacity2, specular_power=specularpower)



# ----------------------------------------------------------------------------------------------------------------------------
# middle layer
# ----------------------------------------------------------------------------------------------------------------------------
x = np.sqrt(3) * a/2 * 3/4

sphere = pv.Sphere(radius=r, center=[a/2, -np.sqrt(3) * a/2 + x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c11, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/2, -np.sqrt(3) * a/2 + x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c11, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, 0+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c11, smooth_shading=True, opacity=opacity1, specular_power=specularpower)



sphere = pv.Sphere(radius=r, center=[-a/2, 0+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/2, 0+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/4, -np.sqrt(3) * a/4+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/4, -np.sqrt(3) * a/4+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[0, -np.sqrt(3)*a/2+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[3*a/4, -np.sqrt(3)*a/4+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-3*a/4, -np.sqrt(3)*a/4+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[-a/4, -3*np.sqrt(3)*a/4+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)

sphere = pv.Sphere(radius=r, center=[a/4, -3*np.sqrt(3) * a/4+x, 0], phi_resolution=resolution, theta_resolution=resolution)
p.add_mesh(sphere, color=c22, smooth_shading=True, opacity=opacity1, specular_power=specularpower)




# ----------------------------------------------------------------------------------------------------------------------------
# plot hexagonal unit cell
# ----------------------------------------------------------------------------------------------------------------------------

line = pv.Line([-a, 0, c/2], [-a/2, np.sqrt(3) * a/2, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line( [-a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a/2, np.sqrt(3) * a/2, c/2], [a, 0, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a, 0, c/2], [a/2, -np.sqrt(3) * a/2, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([-a/2, -np.sqrt(3) * a/2, c/2], [-a, 0, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)





line = pv.Line([-a, 0, -c/2], [-a/2, np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line( [-a/2, np.sqrt(3) * a/2, -c/2], [a/2, np.sqrt(3) * a/2, -c/2])
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a/2, np.sqrt(3) * a/2, -c/2], [a, 0, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a, 0, -c/2], [a/2, -np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a/2, -np.sqrt(3) * a/2, -c/2], [-a/2, -np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([-a/2, -np.sqrt(3) * a/2, -c/2], [-a, 0, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)



line = pv.Line([-a, 0, c/2], [-a, 0, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line( [-a/2, np.sqrt(3) * a/2, c/2], [-a/2, np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a/2, np.sqrt(3) * a/2, c/2], [a/2, np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a, 0, -c/2], [a, 0, c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([a/2, -np.sqrt(3) * a/2, c/2], [a/2, -np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)

line = pv.Line([-a/2, -np.sqrt(3) * a/2, c/2], [-a/2, -np.sqrt(3) * a/2, -c/2], resolution=resolution)
p.add_mesh(line, color=c1, smooth_shading=True, opacity=opacity2, specular_power=specularpower, line_width=linewidth)



p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x24192E501D0>

# %%
fig = plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(p.image)
plt.savefig('test.pdf')
